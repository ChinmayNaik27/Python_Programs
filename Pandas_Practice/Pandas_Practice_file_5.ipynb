# %%
import pandas as pd

# %%
cust=pd.read_csv("E:\\Python data\\datasets\\datasets/shoppingmall.csv")
cust
# Out:
#       ID  Gender  Age  Income  Score
# 0      1    Male   19      15     39
# 1      2    Male   21      15     81
# 2      3  Female   20      16      6
# 3      4  Female   23      16     77
# 4      5  Female   31      17     40
# ..   ...     ...  ...     ...    ...
# 195  196  Female   35     120     79
# 196  197  Female   45     126     28
# 197  198    Male   32     126     74
# 198  199    Male   32     137     18
# 199  200    Male   30     137     83
#
# [200 rows x 5 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
cust
# Out:
#       ID  Gender  Age  Income  Score
# 0      1    Male   19      15     39
# 1      2    Male   21      15     81
# 2      3  Female   20      16      6
# 3      4  Female   23      16     77
# 4      5  Female   31      17     40
# 5      6  Female   22      17     76
# 6      7  Female   35      18      6
# 7      8  Female   23      18     94
# 8      9    Male   64      19      3
# 9     10  Female   30      19     72
# 10    11    Male   67      19     14
# 11    12  Female   35      19     99
# 12    13  Female   58      20     15
# 13    14  Female   24      20     77
# 14    15    Male   37      20     13
# 15    16    Male   22      20     79
# 16    17  Female   35      21     35
# 17    18    Male   20      21     66
# 18    19    Male   52      23     29
# 19    20  Female   35      23     98
# 20    21    Male   35      24     35
# 21    22    Male   25      24     73
# 22    23  Female   46      25      5
# 23    24    Male   31      25     73
# ...

# %%
cust1=pd.read_csv("E:\\Python data\\datasets\\datasets/shopping_customers.csv")
cust1
# Out:
#      ID  Gender  Age  Income  Score
# 0   201    Male   61      31     39
# 1   202    Male   63      31     81
# 2   203  Female   59      23      6
# 3   204  Female   37      23     77
# 4   205  Female   45      19     40
# 5   206  Female   47      19     76
# 6   207  Female   55      32      6
# 7   208  Female   23      24     94
# 8   209    Male   28      25      3
# 9   210  Female   29      17     72
# 10  211    Male   41      18     14
# 11  212  Female   20      19     99
# 12  213  Female   59      21     15
# 13  214  Female   53      22     77
# 14  215    Male   48      22     13
# 15  216    Male   64      26     79
# 16  217  Female   67      26     35
# 17  218    Male   67      27     66
# 18  219    Male   20      28     29
# 19  220  Female   23      24     98

# %%
# combiining 2 dataframes
# SQl Query is select * from cust union all select * from cust1
pd.concat([cust[cust.Income>50],cust1[cust1.Income>45]])
# Out:
#       ID  Gender  Age  Income  Score
# 74    75    Male   59      54     47
# 75    76    Male   26      54     54
# 76    77  Female   45      54     53
# 77    78    Male   40      54     48
# 78    79  Female   23      54     52
# 79    80  Female   49      54     42
# 80    81    Male   57      54     51
# 81    82    Male   38      54     55
# 82    83    Male   67      54     41
# 83    84  Female   46      54     44
# 84    85  Female   21      54     57
# 85    86    Male   48      54     46
# 86    87  Female   55      57     58
# 87    88  Female   22      57     55
# 88    89  Female   34      58     60
# 89    90  Female   50      58     46
# 90    91  Female   68      59     55
# 91    92    Male   18      59     41
# 92    93    Male   48      60     49
# 93    94  Female   40      60     40
# 94    95  Female   32      60     42
# 95    96    Male   24      60     52
# 96    97  Female   47      60     47
# 97    98  Female   27      60     50
# ...

# %%
pd.concat([cust[cust.Income>50],cust1[cust1.Income<45]])
# Out:
#       ID  Gender  Age  Income  Score
# 74    75    Male   59      54     47
# 75    76    Male   26      54     54
# 76    77  Female   45      54     53
# 77    78    Male   40      54     48
# 78    79  Female   23      54     52
# 79    80  Female   49      54     42
# 80    81    Male   57      54     51
# 81    82    Male   38      54     55
# 82    83    Male   67      54     41
# 83    84  Female   46      54     44
# 84    85  Female   21      54     57
# 85    86    Male   48      54     46
# 86    87  Female   55      57     58
# 87    88  Female   22      57     55
# 88    89  Female   34      58     60
# 89    90  Female   50      58     46
# 90    91  Female   68      59     55
# 91    92    Male   18      59     41
# 92    93    Male   48      60     49
# 93    94  Female   40      60     40
# 94    95  Female   32      60     42
# 95    96    Male   24      60     52
# 96    97  Female   47      60     47
# 97    98  Female   27      60     50
# ...

# %%
pd.concat([cust[cust.Income>50],cust1[cust1.Income<45]]).drop_duplicates()
# Out:
#       ID  Gender  Age  Income  Score
# 74    75    Male   59      54     47
# 75    76    Male   26      54     54
# 76    77  Female   45      54     53
# 77    78    Male   40      54     48
# 78    79  Female   23      54     52
# 79    80  Female   49      54     42
# 80    81    Male   57      54     51
# 81    82    Male   38      54     55
# 82    83    Male   67      54     41
# 83    84  Female   46      54     44
# 84    85  Female   21      54     57
# 85    86    Male   48      54     46
# 86    87  Female   55      57     58
# 87    88  Female   22      57     55
# 88    89  Female   34      58     60
# 89    90  Female   50      58     46
# 90    91  Female   68      59     55
# 91    92    Male   18      59     41
# 92    93    Male   48      60     49
# 93    94  Female   40      60     40
# 94    95  Female   32      60     42
# 95    96    Male   24      60     52
# 96    97  Female   47      60     47
# 97    98  Female   27      60     50
# ...

# %%
cust.append({'ID':500,'Gender':'Male','Income':30,'Score':20},ignore_index=True)
# Out:
# C:\Users\chinm\AppData\Local\Temp\ipykernel_10932\2193811018.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cust.append({'ID':500,'Gender':'Male','Income':30,'Score':20},ignore_index=True)
#       ID  Gender   Age  Income  Score
# 0      1    Male  19.0      15     39
# 1      2    Male  21.0      15     81
# 2      3  Female  20.0      16      6
# 3      4  Female  23.0      16     77
# 4      5  Female  31.0      17     40
# 5      6  Female  22.0      17     76
# 6      7  Female  35.0      18      6
# 7      8  Female  23.0      18     94
# 8      9    Male  64.0      19      3
# 9     10  Female  30.0      19     72
# 10    11    Male  67.0      19     14
# 11    12  Female  35.0      19     99
# 12    13  Female  58.0      20     15
# 13    14  Female  24.0      20     77
# 14    15    Male  37.0      20     13
# 15    16    Male  22.0      20     79
# ...

# %%
cust.loc[cust.Score==10,'Score']=11

# %%
cust[cust.Score==11]
# Out:
#       ID Gender  Age  Income  Score
# 128  129   Male   59      71     11
# 138  139   Male   19      74     11
# 172  173   Male   36      87     11

# %%
cust=cust.drop(cust[cust.Score==11].index)
cust
# Out:
#       ID  Gender  Age  Income  Score
# 0      1    Male   19      15     39
# 1      2    Male   21      15     81
# 2      3  Female   20      16      6
# 3      4  Female   23      16     77
# 4      5  Female   31      17     40
# 5      6  Female   22      17     76
# 6      7  Female   35      18      6
# 7      8  Female   23      18     94
# 8      9    Male   64      19      3
# 9     10  Female   30      19     72
# 10    11    Male   67      19     14
# 11    12  Female   35      19     99
# 12    13  Female   58      20     15
# 13    14  Female   24      20     77
# 14    15    Male   37      20     13
# 15    16    Male   22      20     79
# 16    17  Female   35      21     35
# 17    18    Male   20      21     66
# 18    19    Male   52      23     29
# 19    20  Female   35      23     98
# 20    21    Male   35      24     35
# 21    22    Male   25      24     73
# 22    23  Female   46      25      5
# 23    24    Male   31      25     73
# ...

# %%
cust[cust.Score==11]
# Out:
# Empty DataFrame
# Columns: [ID, Gender, Age, Income, Score]
# Index: []

# %%
cust.drop(cust[cust.Score==11].index,inplace=True)

# %%
import numpy as np

# %%
df=pd.DataFrame({'a':[1,2,3,4,5,6,7,8],'b':[10,np.nan,np.nan,20,np.nan,np.nan,30,30]})

# %%
df
# Out:
#    a     b
# 0  1  10.0
# 1  2   NaN
# 2  3   NaN
# 3  4  20.0
# 4  5   NaN
# 5  6   NaN
# 6  7  30.0
# 7  8  30.0

# %%
df['a_cumsum']=df.a.cumsum()
df
# Out:
#    a     b  a_cumsum
# 0  1  10.0         1
# 1  2   NaN         3
# 2  3   NaN         6
# 3  4  20.0        10
# 4  5   NaN        15
# 5  6   NaN        21
# 6  7  30.0        28
# 7  8  30.0        36

# %%
obj=df['a'].rolling(window=2)

# %%
df['a_roll_sum']=obj.sum()

# %%
df
# Out:
#    a     b  a_cumsum  a_roll_sum
# 0  1  10.0         1         NaN
# 1  2   NaN         3         3.0
# 2  3   NaN         6         5.0
# 3  4  20.0        10         7.0
# 4  5   NaN        15         9.0
# 5  6   NaN        21        11.0
# 6  7  30.0        28        13.0
# 7  8  30.0        36        15.0

# %%
obj=df['b'].rolling(window=2,min_periods=2)

# %%
df['b_roll_sum_count']=obj.count()
df
# Out:
#    a     b  a_cumsum  a_roll_sum  b_roll_sum_count
# 0  1  10.0         1         NaN               NaN
# 1  2   NaN         3         3.0               1.0
# 2  3   NaN         6         5.0               0.0
# 3  4  20.0        10         7.0               1.0
# 4  5   NaN        15         9.0               1.0
# 5  6   NaN        21        11.0               0.0
# 6  7  30.0        28        13.0               1.0
# 7  8  30.0        36        15.0               2.0

# %%
obj1=df['a'].expanding(min_periods=1)

# %%
df['a_exp_sum']=obj1.sum()
df
# Out:
#    a     b  a_cumsum  a_roll_sum  b_roll_sum_count  a_exp_sum  a_exp_mean
# 0  1  10.0         1         NaN               NaN        1.0         NaN
# 1  2   NaN         3         3.0               1.0        3.0         NaN
# 2  3   NaN         6         5.0               0.0        6.0         NaN
# 3  4  20.0        10         7.0               1.0       10.0         NaN
# 4  5   NaN        15         9.0               1.0       15.0         NaN
# 5  6   NaN        21        11.0               0.0       21.0         NaN
# 6  7  30.0        28        13.0               1.0       28.0         NaN
# 7  8  30.0        36        15.0               2.0       36.0        30.0

# %%
df['a_exp_mean']=obj1.mean()

# %%
df
# Out:
#    a     b  a_cumsum  a_roll_sum  b_roll_sum_count  a_exp_sum  a_exp_mean
# 0  1  10.0         1         NaN               NaN        NaN         NaN
# 1  2   NaN         3         3.0               1.0        NaN         NaN
# 2  3   NaN         6         5.0               0.0        NaN         NaN
# 3  4  20.0        10         7.0               1.0        NaN         NaN
# 4  5   NaN        15         9.0               1.0        NaN         NaN
# 5  6   NaN        21        11.0               0.0        NaN         NaN
# 6  7  30.0        28        13.0               1.0        NaN         NaN
# 7  8  30.0        36        15.0               2.0       60.0        30.0

# %%
df=pd.read_csv("E:/Python data/datasets/datasets/carprices.csv")

# %%
df
# Out:
#                 car model  mileage  sale price  age  model_date
# 0                  BMW X5    69000       18000    6  12-12-2000
# 1                  BMW X5    35000       34000    3  01-10-2000
# 2                  BMW X5    57000       26100    5  12-05-1995
# 3                  BMW X5    22500       40000    2  20-05-1994
# 4                  BMW X5    46000       31500    4  05-05-1992
# 5                 Audi A5    59000       29400    5  10-10-2002
# 6                 Audi A5    52000       32000    5  10-10-2002
# 7                 Audi A5    72000       19300    6  25-05-2001
# 8                 Audi A5    91000       12000    8  15-09-1997
# 9   Mercedez Benz C class    67000       22000    6  14-09-1998
# 10  Mercedez Benz C class    83000       20000    7  09-09-1996
# 11  Mercedez Benz C class    79000       21000    7  08-09-1999
# 12  Mercedez Benz C class    59000       33000    5  09-09-2004

# %%
df.filter(regex='^m',axis=1)
# Out:
#     mileage  model_date
# 0     69000  12-12-2000
# 1     35000  01-10-2000
# 2     57000  12-05-1995
# 3     22500  20-05-1994
# 4     46000  05-05-1992
# 5     59000  10-10-2002
# 6     52000  10-10-2002
# 7     72000  25-05-2001
# 8     91000  15-09-1997
# 9     67000  14-09-1998
# 10    83000  09-09-1996
# 11    79000  08-09-1999
# 12    59000  09-09-2004

# %%
df_car=df['car model']

# %%
df
# Out:
#                 car model  mileage  sale price  age  model_date
# 0                  BMW X5    69000       18000    6  12-12-2000
# 1                  BMW X5    35000       34000    3  01-10-2000
# 2                  BMW X5    57000       26100    5  12-05-1995
# 3                  BMW X5    22500       40000    2  20-05-1994
# 4                  BMW X5    46000       31500    4  05-05-1992
# 5                 Audi A5    59000       29400    5  10-10-2002
# 6                 Audi A5    52000       32000    5  10-10-2002
# 7                 Audi A5    72000       19300    6  25-05-2001
# 8                 Audi A5    91000       12000    8  15-09-1997
# 9   Mercedez Benz C class    67000       22000    6  14-09-1998
# 10  Mercedez Benz C class    83000       20000    7  09-09-1996
# 11  Mercedez Benz C class    79000       21000    7  08-09-1999
# 12  Mercedez Benz C class    59000       33000    5  09-09-2004

# %%
df_car.str.contains(r'Audi \w+')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# Name: car model, dtype: bool

# %%
df=pd.read_csv("E:\\Python data\\datasets\\datasets\\AAPL Data.csv",parse_dates=['Date'],index_col='Date')

# %%
df
# Out:
#                        Open    High     Low   Close     Volume
# Date
# 2019-10-24 16:00:00   61.13   61.20   60.45   60.90   17916255
# 2019-10-25 16:00:00   60.79   61.68   60.72   61.65   18369296
# 2019-10-28 16:00:00   61.86   62.31   61.68   62.26   24143241
# 2019-10-29 16:00:00   62.24   62.44   60.64   60.82   35709867
# 2019-10-30 16:00:00   61.19   61.33   60.30   60.82   31130522
# 2019-10-31 16:00:00   61.81   62.29   59.32   62.19   34790520
# 2019-01-11 16:00:00   62.39   63.98   62.29   63.96   37781334
# 2019-04-11 16:00:00   64.33   64.46   63.85   64.38   25817952
# 2019-05-11 16:00:00   64.26   64.55   64.08   64.28   19974427
# 2019-06-11 16:00:00   64.19   64.37   63.84   64.31   18966124
# 2019-07-11 16:00:00   64.69   65.09   64.53   64.86   23735083
# 2019-08-11 16:00:00   64.67   65.11   64.21   65.04   17520495
# 2019-11-11 16:00:00   64.58   65.62   64.57   65.55   20507459
# 2019-12-11 16:00:00   65.39   65.70   65.23   65.49   21847226
# ...

# %%
df.loc["2021-12"]
# Out:
#                        Open    High     Low   Close     Volume
# Date
# 2021-12-01 16:00:00  128.50  129.69  126.86  128.80   91951145
# 2021-12-02 16:00:00  134.35  135.53  133.69  135.37   60145130
# 2021-12-03 16:00:00  120.40  121.17  119.16  121.03   88105050
# 2021-12-04 16:00:00  132.52  132.85  130.63  131.24   91419983
# 2021-12-05 16:00:00  123.40  124.64  122.25  122.77  112172282
# 2021-12-07 16:00:00  146.21  146.32  144.00  144.50   76299719
# 2021-12-08 16:00:00  146.19  149.05  145.84  148.89   73779113
# 2021-12-10 16:00:00  143.23  143.25  141.04  141.51   73035859

# %%
 9

# %% [markdown]
# This is First Project in jupiter note book
# 1st program
# Program for addition

# %%
a=int(input("Enter your 1st number:"))
b=int(input("Enter your 2st number:"))
c=a+b
# Out:
# Enter your 1st number:10
# Enter your 2st number:20

# %%
print(c)
# Out:
# 30

# %% [markdown]
# this is a python 1st program end in jupiter
# ![image.png](attachment:image.png)

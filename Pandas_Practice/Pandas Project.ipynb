# %% [markdown]
# # Project on Pandas By Chinmay Naik
# ## This is a Project on world alcohol consumption
# ### As per requirement...

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\Big-Data-Files & notes\\Python\\PANDAS-PROJECT\\PANDAS-PROJECT\\world_alcohol_comsumption.csv")

# %%
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# ...

# %%
pd.set_option("display.max_rows",None)

# %%
df
# Out:
#     Year             WHO region  \
# 0   1986        Western Pacific
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 6   1987                 Africa
# 7   1985                 Africa
# 8   1986               Americas
# 9   1984                 Africa
# 10  1987                 Africa
# 11  1989               Americas
# 12  1985        Western Pacific
# 13  1984  Eastern Mediterranean
# 14  1985        Western Pacific
# 15  1987                 Africa
# 16  1984               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 20  1986        South-East Asia
# 21  1989               Americas
# 22  1984                 Europe
# 23  1984                 Europe
# 24  1985                 Africa
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# ...

# %%
#al consumption in yr 1987 or 1989
df.columns
# Out:
# Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
df[(df.Year==1987) | (df.Year==1989)]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# ...

# %%
res=df[(df.Year==1987) | (df.Year==1989)].count()

# %%
res
# Out:
# Year              39
# WHO region        39
# Country           39
# Beverage Types    39
# Display Value     38
# dtype: int64

# %%
"""find out and display horizontal bar chart the alcohol consumption 
details in the year '1986' 
where WHO region is 'Western Pacific' and country is 'VietNam' 
from thedataset."""
df[(df.Year==1986) & (df['WHO region']=="Western Pacific") & (df.Country=="Viet Nam")].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# for 1987
res=df[df.Year==1987].where((df['WHO region']=="Western Pacific") & (df.Country=="Viet Nam"))
res=res.dropna()
res
# Out:
#       Year       WHO region   Country Beverage Types  Display Value
# 28  1987.0  Western Pacific  Viet Nam           Beer           0.11
# 56  1987.0  Western Pacific  Viet Nam           Wine           0.00

# %%
res.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#with names
res1=res
res1
# Out:
#       Year       WHO region   Country Beverage Types  Display Value
# 28  1987.0  Western Pacific  Viet Nam           Beer           0.11
# 56  1987.0  Western Pacific  Viet Nam           Wine           0.00

# %%
import matplotlib.pyplot as plt
plt.barh('Beverage Types','Display Value',data=res1,label='1987',color='red')
plt.xlabel("Alcohol Consumption-->>")
plt.xlabel("Western Pacfic Vietnam-->>")
plt.legend()

# %%
"""find and display bar chart to out the alcohol consumption details in the year '1986' or '1989' where WHO region is 'Americas'
or 'Europe' from the world alcohol consumption dataset.Use Different colors for each bar and attach text label above each bar."""
res1=df[(df.Year==1986) | (df.Year==1989)].where((df['WHO region']=='Americas') | (df['WHO region']=='Europe')).dropna()
res1
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 11  1989.0   Americas                         Guatemala           Beer
# 21  1989.0   Americas                        Costa Rica        Spirits
# 34  1986.0     Europe                Russian Federation           Wine
# 37  1986.0     Europe                            Sweden           Beer
# 41  1986.0     Europe                    Czech Republic           Beer
# 47  1986.0   Americas                            Mexico          Other
# 49  1986.0     Europe                             Malta           Wine
# 55  1989.0   Americas                          Suriname           Wine
# 57  1989.0     Europe                           Croatia           Wine
# ...

# %%
res2=res1[res1.Year==1986]
res3=res1[res1.Year==1989]
res2
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 34  1986.0     Europe                Russian Federation           Wine
# 37  1986.0     Europe                            Sweden           Beer
# 41  1986.0     Europe                    Czech Republic           Beer
# 47  1986.0   Americas                            Mexico          Other
# 49  1986.0     Europe                             Malta           Wine
# 74  1986.0   Americas  Bolivia (Plurinational State of)        Spirits
# 86  1986.0   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 34           0.80
# 37           3.04
# 41           6.82
# 47           0.04
# 49           1.49
# ...

# %%
res3
# Out:
#       Year WHO region                           Country Beverage Types  \
# 11  1989.0   Americas                         Guatemala           Beer
# 21  1989.0   Americas                        Costa Rica        Spirits
# 55  1989.0   Americas                          Suriname           Wine
# 57  1989.0     Europe                           Croatia           Wine
# 64  1989.0   Americas  Bolivia (Plurinational State of)           Beer
# 78  1989.0   Americas                           Jamaica          Other
# 79  1989.0     Europe                           Finland          Other
# 91  1989.0     Europe                          Bulgaria           Beer
#
#     Display Value
# 11           0.62
# 21           4.51
# 55           0.04
# 57           5.10
# 64           1.26
# 78           0.00
# 79           2.09
# 91           4.43

# %%
plt.bar('WHO region','Display Value',data=res2,label=1986,color='red')
plt.legend()
plt.xlabel("Who regions---->")
plt.ylabel("Alcohol Consumptions---->")
# Out:
# Text(0, 0.5, 'Alcohol Consumptions---->')

# %%
plt.bar('WHO region','Display Value',data=res3,label=1989,color='green')
plt.legend()
plt.xlabel("Who regions---->")
plt.ylabel("Alcohol Consumptions---->")
# Out:
# Text(0, 0.5, 'Alcohol Consumptions---->')

# %%
#find out the 'WHO region, 'Country', 'Beverage Types' in the year '1986' or '1989'  where WHO region is 'Americas' or 'Europe' from the world alcohol consumption dataset.
res=df[(df.Year==1986) | (df.Year==1989)][['WHO region','Country','Beverage Types']].where((df['WHO region']=='Americas')|(df['WHO region']=='Europe')).dropna()

# %%
res
# Out:
#    WHO region                           Country Beverage Types
# 1    Americas                           Uruguay          Other
# 3    Americas                          Colombia           Beer
# 8    Americas               Antigua and Barbuda        Spirits
# 11   Americas                         Guatemala           Beer
# 21   Americas                        Costa Rica        Spirits
# 29     Europe                             Italy          Other
# 34     Europe                Russian Federation           Wine
# 37     Europe                            Sweden           Beer
# 41     Europe                    Czech Republic           Beer
# 47   Americas                            Mexico          Other
# 49     Europe                             Malta           Wine
# 55   Americas                          Suriname           Wine
# 57     Europe                           Croatia           Wine
# 64   Americas  Bolivia (Plurinational State of)           Beer
# ...

# %%
# find out the records where consumption of beverages per person average >=5 
# and Beverage Types is Beer from world alcohol consumption dataset.
res=df[(df['Display Value']>=5) & (df['Beverage Types']=="Beer")]
res
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %%
# find out and display Pie chart of the records where consumption of beverages per person average >=4 and 
# Beverage Types is Beer, Wine, Spirits from world alcohol consumption dataset.
res1=df[(df['Display Value']>=4) & (df['Beverage Types'] =='Beer')] ['Display Value']
res2=df[(df['Display Value']>=4) & (df['Beverage Types'] =='Wine')] ['Display Value']
res3=df[(df['Display Value']>=4) & (df['Beverage Types'] =='Spirits')] ['Display Value']

# %%
print(res1, res2, res3)
# Out:
# 3     4.27
# 41    6.82
# 91    4.43
# Name: Display Value, dtype: float64 57    5.10
# 96    7.38
# Name: Display Value, dtype: float64 21    4.51
# Name: Display Value, dtype: float64

# %%
plt.pie(res1,shadow=True,autopct='%.1f%%')
plt.show()

# %%
plt.pie(res2,shadow=True,autopct='%.1f%%')
plt.show()
plt.pie(res3,shadow=True,autopct='%.1f%%')
plt.show()

# %%
#the WHO region and Beverage Types columns and records by range from 0 to 15 
#from dataset.
res=df.loc[0:15,['WHO region','Beverage Types']]

# %%
res
# Out:
#                WHO region Beverage Types
# 0         Western Pacific           Wine
# 1                Americas          Other
# 2                  Africa           Wine
# 3                Americas           Beer
# 4                Americas           Beer
# 5                Americas          Other
# 6                  Africa           Wine
# 7                  Africa        Spirits
# 8                Americas        Spirits
# 9                  Africa          Other
# 10                 Africa           Wine
# 11               Americas           Beer
# 12        Western Pacific           Beer
# 13  Eastern Mediterranean          Other
# 14        Western Pacific        Spirits
# 15                 Africa           Wine

# %%
#using iloc
res1=df.iloc[0:16,[1,3]]
res1
# Out:
#                WHO region Beverage Types
# 0         Western Pacific           Wine
# 1                Americas          Other
# 2                  Africa           Wine
# 3                Americas           Beer
# 4                Americas           Beer
# 5                Americas          Other
# 6                  Africa           Wine
# 7                  Africa        Spirits
# 8                Americas        Spirits
# 9                  Africa          Other
# 10                 Africa           Wine
# 11               Americas           Beer
# 12        Western Pacific           Beer
# 13  Eastern Mediterranean          Other
# 14        Western Pacific        Spirits
# 15                 Africa           Wine

# %%
# WHO region contains "Ea" substring from dataset and show count of it.
res=df['WHO region']
res1=res[res.str.contains('Ea')]
res1.count()
# Out:
# 22

# %%
len(res1)
# Out:
# 22

# %%
# to filter those records where WHO region matches with multiple values
# (Africa, Eastern Mediterranean, Europe) from dataset

# %%
res[(res.str.contains('^Ea')) | (res.str.contains('^Af')) | (res.str.contains('^Eu'))]
#or optimised way given below
# Out:
# 2                    Africa
# 6                    Africa
# 7                    Africa
# 9                    Africa
# 10                   Africa
# 13    Eastern Mediterranean
# 15                   Africa
# 17                   Africa
# 18                   Europe
# 19                   Africa
# 22                   Europe
# 23                   Europe
# 24                   Africa
# 25    Eastern Mediterranean
# 26                   Europe
# 27    Eastern Mediterranean
# 29                   Europe
# 30                   Africa
# 32                   Africa
# 33                   Africa
# 34                   Europe
# 36    Eastern Mediterranean
# 37                   Europe
# 38    Eastern Mediterranean
# 39                   Africa
# 40                   Europe
# 41                   Europe
# 42                   Europe
# 44                   Europe
# 45                   Africa
# 49                   Europe
# 50                   Europe
# 51                   Europe
# ...

# %%
df1=df.rename(columns={'WHO region':'WHO_region'})
df1.query('WHO_region in ["Africa","Europe","Eastern Mediterranean"]')
# Out:
#     Year             WHO_region  \
# 2   1985                 Africa
# 6   1987                 Africa
# 7   1985                 Africa
# 9   1984                 Africa
# 10  1987                 Africa
# 13  1984  Eastern Mediterranean
# 15  1987                 Africa
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 22  1984                 Europe
# 23  1984                 Europe
# 24  1985                 Africa
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 29  1986                 Europe
# 30  1986                 Africa
# 32  1989                 Africa
# 33  1985                 Africa
# 34  1986                 Europe
# 36  1987  Eastern Mediterranean
# 37  1986                 Europe
# 38  1987  Eastern Mediterranean
# 39  1987                 Africa
# 40  1987                 Europe
# 41  1986                 Europe
# 42  1984                 Europe
# ...

# %%
# filter those records which not appears in a given list from dataset.
# who_region = ["Africa", "Eastern Mediterranean", "Europe"]
df1.query("WHO_region not in ['Africa','Eastern Mediterranean','Europe']")
# Out:
#     Year       WHO_region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# ...

# %%
# create bar plots with error bars to filter all records 
# where the average consumption of beverages per person from 0.5 to 2.50 in dataset.
res=df[(df['Display Value']>=0.5) & (df['Display Value']<=2.5)]
res
res1=res['Beverage Types']
res2=res['Display Value']

# %%
plt.bar(res1,res2,label="Beverages",color='violet')
plt.ylabel("Beverage Consuption avg -->")
plt.xlabel("Beverage Type -->")
plt.legend()
plt.show()

# %%
# find average consumption of wine per person greater than 2 in world alcohol consumption dataset.
res=df[(df['Display Value']>2) & (df['Beverage Types']=='Wine')]
res
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %%
# filter rows, based on row numbers ended with 0, like 0, 10, 20, 30 from dataset.
lst=range(0,100,10)
lst=list(lst)
rows=df.iloc[lst,:]
rows
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %%
# select rows with Index label 0 to 9 with some columns from dataset.
lst=list(range(0,10))
df.iloc[lst,1:4]
# Out:
#         WHO region                Country Beverage Types
# 0  Western Pacific               Viet Nam           Wine
# 1         Americas                Uruguay          Other
# 2           Africa           Cte d'Ivoire           Wine
# 3         Americas               Colombia           Beer
# 4         Americas  Saint Kitts and Nevis           Beer
# 5         Americas              Guatemala          Other
# 6           Africa              Mauritius           Wine
# 7           Africa                 Angola        Spirits
# 8         Americas    Antigua and Barbuda        Spirits
# 9           Africa                Nigeria          Other

# %%
# filter all columns where all entries present, check which rows and columns has a 
# NaN and finally drop rows with any NaNs from world alcohol consumption dataset.
df.isnull().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     0
# dtype: int64

# %%
# filter all records starting from the 'Year' column,
# access every other column from world alcohol consumption dataset.
len(df.columns)
# Out:
# 5

# %%
lst=list(range(0,len(df.columns),2))
df.iloc[:,lst]
# Out:
#     Year                                            Country  Display Value
# 0   1986                                           Viet Nam           0.00
# 1   1986                                            Uruguay           0.50
# 2   1985                                       Cte d'Ivoire           1.62
# 3   1986                                           Colombia           4.27
# 4   1987                              Saint Kitts and Nevis           1.98
# 5   1987                                          Guatemala           0.00
# 6   1987                                          Mauritius           0.13
# 7   1985                                             Angola           0.39
# 8   1986                                Antigua and Barbuda           1.55
# 9   1984                                            Nigeria           6.10
# 10  1987                                           Botswana           0.20
# ...

# %%
# filter all records starting from the 2nd row, 
# access every 5th row from dataset.
lst=list(range(2,len(df),5))
lst
# Out:
# [2, 7, 12, 17, 22, 27, 32, 37, 42, 47, 52, 57, 62, 67, 72, 77, 82, 87, 92]

# %%
df.iloc[lst,:]
# Out:
#     Year             WHO region                           Country  \
# 2   1985                 Africa                      Cte d'Ivoire
# 7   1985                 Africa                            Angola
# 12  1985        Western Pacific  Lao People's Democratic Republic
# 17  1989                 Africa                        Seychelles
# 22  1984                 Europe                           Romania
# 28  1987        Western Pacific                          Viet Nam
# 34  1986                 Europe                Russian Federation
# 39  1987                 Africa                      Burkina Faso
# 45  1989                 Africa                          Zimbabwe
# 50  1985                 Europe                       Switzerland
# 55  1989               Americas                          Suriname
# 60  1987  Eastern Mediterranean        Iran (Islamic Republic of)
# 65  1989  Eastern Mediterranean                           Somalia
# ...

# %%
#to rename all and only some of the
# column names from dataset by adding _ in column names.
df.rename(columns={'WHO region':'Who_region','Beverage Types':'Beverage_types','Display Value':'Display_values'},inplace=True)

# %%
df
# Out:
#     Year             Who_region  \
# 0   1986        Western Pacific
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 6   1987                 Africa
# 7   1985                 Africa
# 8   1986               Americas
# 9   1984                 Africa
# 10  1987                 Africa
# 11  1989               Americas
# 12  1985        Western Pacific
# 13  1984  Eastern Mediterranean
# 14  1985        Western Pacific
# 15  1987                 Africa
# 16  1984               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 20  1986        South-East Asia
# 21  1989               Americas
# 22  1984                 Europe
# 23  1984                 Europe
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 28  1987        Western Pacific
# ...

# %%
#find which years have all non-zero values
# and which years have any non-zero values from dataset.
df.isnull().sum()
df.dropna()
# Out:
#     Year             WHO region  \
# 0   1986        Western Pacific
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 6   1987                 Africa
# 7   1985                 Africa
# 8   1986               Americas
# 9   1984                 Africa
# 10  1987                 Africa
# 11  1989               Americas
# 12  1985        Western Pacific
# 13  1984  Eastern Mediterranean
# 14  1985        Western Pacific
# 15  1987                 Africa
# 16  1984               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 20  1986        South-East Asia
# 21  1989               Americas
# 22  1984                 Europe
# 23  1984                 Europe
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 28  1987        Western Pacific
# ...

# %%
#any nonzero value
df.isnull().sum()
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64

# %%
df
# Out:
#     Year             WHO region  \
# 0   1986        Western Pacific
# 1   1986               Americas
# 2   1985                 Africa
# 3   1986               Americas
# 4   1987               Americas
# 5   1987               Americas
# 6   1987                 Africa
# 7   1985                 Africa
# 8   1986               Americas
# 9   1984                 Africa
# 10  1987                 Africa
# 11  1989               Americas
# 12  1985        Western Pacific
# 13  1984  Eastern Mediterranean
# 14  1985        Western Pacific
# 15  1987                 Africa
# 16  1984               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 20  1986        South-East Asia
# 21  1989               Americas
# 22  1984                 Europe
# 23  1984                 Europe
# 24  1985                 Africa
# 25  1984  Eastern Mediterranean
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# ...
